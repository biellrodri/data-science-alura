# %% [markdown]
# ## **Tendência de Imigração**
#
# Uma empresa que presta serviços de consultoria e aconselhamentos para pessoas que querem imigrar do Brasil para o Canadá, quer melhorar seus serviços. Para isso, recebemos alguns arquivos disponibilizados para fazer uma análise das **tendências de imigração do Brasil nos últimos anos**. E entre esses arquivos há um **arquivo csv** que contém informações de todos os países com o número aproximado de imigrantes para cada um dos anos desde 1980. Será com esse arquivo que iremos trabalhar.

# %%
#importando a biblioteca pandas
import pandas as pd

# %%
#importando o arquivo csv
df = pd.read_csv('imigrantes_canada.csv')
#visualizando o DataFrame
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
#obter informações mais detalhadas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %% [markdown]
# Ao analisar as informações acima, vemos que **não há valores nulos** por tanto, não será necessário fazer um tratamento de nenhum dado nulo ou mudar algum tipo de dado.

# %% [markdown]
# ### **Analisar as Tendências de Imigração do Brasil em um Determinado Período**
#
# Primeiro passo a ser feito é deixar o **índex** do DataFrame como **país** para, acessar apenas o **Brasil** e extrair as informações dele

# %%
#mudar o index
df.set_index('País', inplace=True)

# %%
#criar uma variável para armazenar o intervalo  de tempo desde 1980 até 2013
anos = list(map(str, range(1980, 2014)))

# %%
#pegando apenas os dados do Brasil
brasil = df.loc['Brasil', anos]

# %%
#verificando os dados obtidos
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
#transformando a serie acima em um DataFrame
#criando um dicionário para atribuir nome às colunas e seus valores
brasil_dict = {'ano': brasil.index.tolist(), 'imigrantes' : brasil.values.tolist()}
#utilizando o dicionário criado para criar o DataFrame
dados_brasil = pd.DataFrame(brasil_dict)

# %%
#visualizando o DataFrame criado
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %% [markdown]
# ### **Gerar o gráfico**

# %%
#importando a biblioteca matplotlib
import matplotlib.pyplot as plt

# %%
#gerando um gráfico de linha com os anos do DataFrame
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])

# %% [markdown]
# ### **Melhorando a Visualização do Gráfico**

# %%
#alterando o tamanho do gráfico
plt.figure(figsize=(8, 4))
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
#adiciondo o título
plt.title('Imigração do Brasil para o Canadá')
#adicionando a descrição do eixo x
plt.xlabel('Ano')
#adicionando a descrição do eixo y
plt.ylabel('Número de imigrantes')
#aplicando um intervalo entre os anos de 5 em 5 anos
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
#exibindo o gráfico
plt.show()

# %% [markdown]
# ### **Figura**

# %%
#criando uma figura
fig, ax = plt.subplots(figsize=(8, 4))
#passando as informações dos eixos x e y
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
#adicionando o título à figura
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013')
#adicionando a descrição do eixo x
ax.set_xlabel('Ano')
#adicionando a descrição do eixo y
ax.set_ylabel('Número de imigrantes')
#adicionando um intervalo de 5 em 5 anos para o eixo x
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
#exibindo a figura
plt.show()

# %% [markdown]
# ### **Boxplot**

# %%
#criando a figura com dois subplots
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
#primeiro gráfico
axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
#adicionando o título
axs[0].set_title('Imigração do Brasil para o Canadá\n1980 a 2013')
#adicionando a descrição do eixo x
axs[0].set_xlabel('Ano')
#adicionando a descrição do eixo x
axs[0].set_ylabel('Número de imigrantes')
#inserindo um intervalo de tempo de 5 em 5 anos no eixo x
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
#adicionando um grid para visualizar melhor à qual ano corresponde cada número de imigrantes
axs[0].grid()

#segundo gráfico
axs[1].boxplot(dados_brasil['imigrantes'])
#adicionando o título
axs[1].set_title('Boxplot da imigração do Brasil para o Canadá\n1980 a 2013')
#adicionando a descrição do eixo x
axs[1].set_xlabel('Brasil')
#adicionando a descrição do eixo x
axs[1].set_ylabel('Número de imigrantes')
#adicionando um grid para visualizar melhor à qual ano corresponde cada número de imigrantes
axs[1].grid()
plt.show()

# %%
#descrevendo as informações obtidas
dados_brasil.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %% [markdown]
# ### **Tendência de imigração dos 4 maiores países da América do Sul**
#
# Agora o objetivo será criar uma figura com **quatro subplots** para analisar a **tendência de imigração** para os quatro maiores países da **América do Sul**
#
# - **Brasil**
# - **Colômbia**
# - **Peru**
# - **Argentina**

# %%
#criando a figura
fig, axs = plt.subplots(2, 2, figsize=(10,6))
#ajustando o espaçamento entre os subplots
fig.subplots_adjust(hspace=0.5, wspace=0.3)
#adicionando um título geral
fig.suptitle('Imigração dos quatro maiores países da A')


#primeiro subplot
axs[0,0].plot(df.loc['Brasil', anos])
axs[0,0].set_title('Brasil')

#segundo subplot
axs[0,1].plot(df.loc['Colômbia', anos])
axs[0,1].set_title('Colômbia')

#terceiro subplot
axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_title('Argentina')

#quarto subplot
axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_title('Peru')

#utilizando a estrutura for para adicionar intervalo de tempo de 5 em 5 anos aos eixos x dos subplots
for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))

#utilizando a estrutura for para adicionar as descrições dos eixos x e y
for ax in axs.flat:
    ax.set_xlabel('Ano')
    ax.set_ylabel('Número de imigrantes')

#determinando valores mínimo e máximo para o eixo y
ymin = 0
ymax = 7000

#instrução for para ajustar esses valores
for ax in axs.ravel():
    ax.set_ylim(ymin, ymax)
    
#exibindo a figura
plt.show()

# %% [markdown]
# ### **Personalizando Visualizações com Matplotlib**
#
# Agora iremos customizar ainda mais o nosso gráfico, modificando o **tamanho de fontes**, mudando **as cores**, adicionando **mais informações**.
#
# Para isso, começaremos mudando o **gráfico onde tínhamos apenas os dados do Brasil**. Faremos algumas modificações para **melhorar a visualização**.

# %%
#criando uma figura
fig, ax = plt.subplots(figsize=(8, 4))
#passando as informações dos eixos x e y
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3,)
#adicionando o título à figura
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013', fontsize=18, loc='left')
#adicionando a descrição do eixo x
ax.set_xlabel('Ano', fontsize=14)
#adicionando a descrição do eixo y
ax.set_ylabel('Número de imigrantes', fontsize=14)
#modificando o tamanho dos ticks do eixo x
ax.xaxis.set_tick_params(labelsize=12)
#modificando o tamanho dos ticks do eixo y
ax.yaxis.set_tick_params(labelsize=12)
#adicionando um intervalo de 5 em 5 anos para o eixo x
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
#adicionando o grid
plt.grid(linestyle='--')
#exibindo a figura
plt.show()

# %% [markdown]
# ### **Alterando Cores**
#
# As cores são uma **ferramenta poderosa em visualizações de dados**. Elas podem nos ajudar a **transmitir as informações**, **destacar alguns padrões** e **identificar algumas tendências**. Algumas opções de cores incluem:
#
# - *Base colors*;
# - *Tableau palette*;
# - *CSS colors*.
#
# As **base colors** são as cores mais básicas pré-definidas e na frente do retângulo de cada cor temos a letra que representa a cor. São elas **azul(b)**, **verde(g)**, **vermelho(r)**, **ciano(c)**, **magenta(m)**, **amarelo(y)**, **preto(k)** e **branco(w)**.
#
# A **tableau pallet** contém outras cores pré-definidas e bem distintas entre si, sendo ideal para trabalhar com **dados categóricos**.
#
# Por fim, temos as **CSS colors**, usadas para **aplicações web** e **criação de interfaces**.

# %%
#criando uma figura
fig, ax = plt.subplots(figsize=(8, 4))
#passando as informações dos eixos x e y
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, color='g')
#adicionando o título à figura
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013', fontsize=18, loc='left')
#adicionando a descrição do eixo x
ax.set_xlabel('Ano', fontsize=14)
#adicionando a descrição do eixo y
ax.set_ylabel('Número de imigrantes', fontsize=14)
#modificando o tamanho dos ticks do eixo x
ax.xaxis.set_tick_params(labelsize=12)
#modificando o tamanho dos ticks do eixo y
ax.yaxis.set_tick_params(labelsize=12)
#adicionando um intervalo de 5 em 5 anos para o eixo x
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

#removendo os frames do topo e da direita para melhorar a visualização
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#salvando a figura em formato png
fig.savefig('imigracao_brasil_canada.png', transparent=False, dpi=300, bbox_inches='tight')

#exibindo a figura
plt.show()

# %% [markdown]
# ### **Comparando os dados do Brasil com todos os países da América do Sul**
#
# Vamos avaliar o **número total de imigrantes** de cada um desses países e verificar como o **Brasil** está posicionado em relação a isso nesse período.

# %%
#verificar algumas informações do nosso DataFrame
df.head()
# Out:
#                 Continente           Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia      Sul da Ásia    16    39    39    47    71
# Albânia             Europa    Sul da Europa     1     0     0     0     0
# Argélia             África  Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia        Polinésia     0     1     0     0     0
# Andorra             Europa    Sul da Europa     0     0     0     0     0
#
#                  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Afeganistão       340   496   741  ...  3436  3009  2652  2111  1746  1758
# Albânia             0     1     2  ...  1223   856   702   560   716   561
# Argélia            44    69   132  ...  3626  4807  3623  4005  5393  4752
# Samoa Americana     0     0     1  ...     0     1     0     0     0     0
# Andorra             0     2     0  ...     0     1     1     0     0     0
#
# ...

# %% [markdown]
# Podemos ver no DataFrame que as informações são separadas por **País**, **Continente** e **Região**. Para selecionar apenas os países da América do Sul
# é possível fazer uma **query** pegando somente a região que seja **América do Sul**

# %%
#criando uma variável coom a query 
america_sul = df.query('Região == "América do Sul"')

# %%
#visualizando os dados da variável criada
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %% [markdown]
# Ao verificar o DataFrame podemos observar que há 12 países da América do Sul, e com base nisso, iremos plotar um gráfico que contenha o **número total
# de imigrações** de cada um dos países. Quando falamos de gráficos que contém **quantidade**, o ideal é usar um **gráfico de barras**.

# %%
#ordenando os valores do DataFrame em ordem crescente
america_sul_sorted = america_sul.sort_values('Total', ascending=True)

# %%
#atribuindo as cores que serão utilizadas no gráfico a uma variável
cores = ['royalblue', 'orange', 'forestgreen', 'orchid',
'purple', 'brown', 'slateblue', 'gray', 'olive', 'teal',
'tomato']

#criando uma figura
fig, ax = plt.subplots(figsize=(12, 5))
#definindo os eixos da barra
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
#inserindo um título ao gráfico
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
#inserindo título dos rótulos
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
#tamanho dos ticks do eixo x
ax.xaxis.set_tick_params(labelsize=12)
#tamanho dos ticks do eixo y
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %% [markdown]
# No gráfico gerado acima, observamos que o Brasil está em **4º lugar**. Como nosso projeto o foco principal é em relação aos dados do **Brasil**, podemos **destacá-lo** das demais colunas

# %%
#criando uma lista de cores vazia
cores = []
#criando condição for
for pais in america_sul_sorted.index:
    if pais == 'Brasil':
        cores.append('green')
    else:
        cores.append('silver')


#criando uma figura
fig, ax = plt.subplots(figsize=(12, 5))
#definindo os eixos da barra
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
#inserindo um título ao gráfico
ax.set_title('América do Sul: Brasil foi o 4º país com mais imigrantes\npara o Canadá no período de 1980 a 2013', loc='left', fontsize=18)
#inserindo título dos rótulos
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
#tamanho dos ticks do eixo x
ax.xaxis.set_tick_params(labelsize=12)
#tamanho dos ticks do eixo y
ax.yaxis.set_tick_params(labelsize=12)

#criando uma condição para acrescentar texto às barras
for i, v in enumerate(america_sul_sorted['Total']):
    ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va='center')

#retirando o frame do gráfico
ax.set_frame_on(False)

#retirando a vissualização do eixo x
ax.get_xaxis().set_visible(False)

#retirando os marcadores dos eixos
ax.tick_params(axis='both', which='both', length=0)

#salvando o gráfico em formato png
fig.savefig('imigracao_america_sul.png', transparent=False, dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### **Salvando os Gráficos**
#
# Os arquivos serão salvos no formato **png**, por ser um formato amplamente aceito por **softwares** e ter uma boa **resolução**

# %%
#visualizando os formatos que os gráficos podem ser salvos
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %% [markdown]
# ## **Seaborn**

# %% [markdown]
# A próxima etapa do projeto é ter uma **visualização global** da imigração desses países para o **Canadá**

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Gabri\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Gabri\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Gabri\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
import seaborn as sns

# %%
#adicionando o tema padrão
sns.set_theme()

# %%
#criando um ranking de top 10
top_10 = df.sort_values('Total', ascending=False).head(10)

# %%
top_10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
#gerando um gráfico de barras
sns.barplot(data=top_10, x=top_10.index, y='Total')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
#gerando o gráfico de barras na horizontal
sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
#adicionando um título
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')

ax.set(title='Países com maior imigração para o Canadá\n1980 a 2013',
      xlabel='Número de imigrantes',
      ylabel='')

#exibindo o gráfico
plt.show()

# %%
#criando uma figura para poder personalizar ainda mais o gráfico
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')

ax.set_title('Países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=16)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')
plt.show()

# %%
#função que pergunta o nome da paleta de cores
def gerar_grafico_paleta(palette):
    fig, ax = plt.subplots(figsize=(8,4))
    
    ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', hue=top_10.index, palette=palette, legend=False)
    ax.set_title('Países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=18)
    ax.set_xlabel('Número de imigrantes', fontsize=14)
    ax.set_ylabel('')
    
    plt.show()

# %% [markdown]
# ### **Paletas de Cores Sequenciais**

# %%
#gerando o gráfico 
gerar_grafico_paleta('Blues_r')

# %% [markdown]
# ### **Paleta Divergente**

# %%
gerar_grafico_paleta('rocket')

# %%
gerar_grafico_paleta('coolwarm')

# %% [markdown]
# ### **Paleta Categórica**

# %%
gerar_grafico_paleta('tab10')

# %% [markdown]
# ### **Conhecendo alguns temas da biblioteca seaborn**

# %%
#definindo o tema
sns.set_theme(style='dark')
#gerando o gráfico
gerar_grafico_paleta('tab10')

# %%
#definindo o tema
sns.set_theme(style='whitegrid')
#gerando o gráfico
gerar_grafico_paleta('tab10')

# %%
#definindo o tema
sns.set_theme(style='white')
#gerando o gráfico
gerar_grafico_paleta('tab10')

# %%
#definindo o tema
sns.set_theme(style='ticks')
#gerando o gráfico
gerar_grafico_paleta('tab10')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', hue=top_10.index, palette='tab10', legend=False)

ax.set_title('Países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=14)
ax.set_ylabel('')

#retirando o frame do gráfico
sns.despine()

plt.show()
